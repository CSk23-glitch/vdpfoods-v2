# %%
import os
from pymongo import MongoClient
from dotenv import load_dotenv

# Load .env if needed
load_dotenv()

# 🔹 SOURCE DATABASE
SOURCE_URI = "mongodb+srv://videepthafoods:1ZDiNL2NGKcvKyp5@cluster0.v6jawym.mongodb.net/ecommerce_db?retryWrites=true&w=majority&appName=Cluster0"

SOURCE_DB_NAME = "ecommerce_db"

# 🔹 TARGET DATABASE
TARGET_URI = "mongodb://admin:S_99_chi_231999@187.77.186.154:27017/"
TARGET_DB_NAME = "ecommerce_db"
print("Source DB:", SOURCE_DB_NAME)
print("Target DB:", TARGET_DB_NAME)

if not all([SOURCE_URI, SOURCE_DB_NAME, TARGET_URI, TARGET_DB_NAME]):
    print("❌ Missing environment variables.")
    exit()

# Connect
source_client = MongoClient(SOURCE_URI)
target_client = MongoClient(TARGET_URI)

source_db = source_client[SOURCE_DB_NAME]
target_db = target_client[TARGET_DB_NAME]

collections = source_db.list_collection_names()

print("📦 Collections found:", collections)

for collection_name in collections:
    print(f"\n🚀 Copying collection: {collection_name}")

    source_collection = source_db[collection_name]
    target_collection = target_db[collection_name]

    # OPTIONAL: clear target collection first
    target_collection.delete_many({})

    documents = list(source_collection.find())

    if documents:
        target_collection.insert_many(documents)
        print(f"✅ Copied {len(documents)} documents")
    else:
        print("⚠ No documents found")

print("\n🎉 Database migration completed successfully!")
# Out:
# Source DB: ecommerce_db
# Target DB: ecommerce_db
# 📦 Collections found: ['accounts_pendingsignup', 'support_tickets', 'accounts_encryptedprofile', 'navigation', 'category', 'products', 'page', 'accounts_address', 'policies', 'auth_user', 'django_session', 'promotions', 'django_migrations', 'accounts_refreshtoken', 'coupons', 'stock', 'accounts_customer_profile', 'orders', 'stories', 'categories', 'auth_permission', 'heroes', 'accounts_otpstore', 'pages', 'accounts_admin_profile', 'django_content_type', 'theme']
#
# 🚀 Copying collection: accounts_pendingsignup
# ✅ Copied 2 documents
#
# 🚀 Copying collection: support_tickets
# ⚠ No documents found
#
# 🚀 Copying collection: accounts_encryptedprofile
# ⚠ No documents found
#
# 🚀 Copying collection: navigation
# ✅ Copied 1 documents
#
# 🚀 Copying collection: category
# ⚠ No documents found
#
# 🚀 Copying collection: products
# ✅ Copied 4 documents
#
# 🚀 Copying collection: page
# ⚠ No documents found
#
# ...
